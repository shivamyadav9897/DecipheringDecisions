# %% [markdown]
# **question**-**01**
#
# Step 1: Eliminate strictly dominated strategies for Player 1
#
#
# For Player 1 (rows a, b, c, d):
#
# Compare row a with other rows:
#
#
# Row a is dominated by row c because 5 > 1, 4 > 2, and 7 > 5.
#
#
# Compare row b with other rows:
#
#
# Row b is dominated by row c because 5 > 4, 4 > 3, and 7 > 3.
#
#
# Compare row d with other rows:
#
#
# Row d is dominated by row c because 5 > 2, 4 > 0, and 7 > 3.
#
#
# Eliminate rows a, b, and d. Remaining strategy for Player 1 is:
#
#
#    1         2         3
# c (5, 2)   (4, 4)   (7, 0)
#
#
# Step 2: Eliminate strictly dominated strategies for Player 2
#
#
# For Player 2 (columns 1, 2, 3):
#
# Compare column 1 with other columns:
#
#
# Column 1 is dominated by column 2 because 4 > 2.
#
#
# Compare column 3 with other columns:
#
#
# Column 3 is dominated by column 2 because 4 > 3.
#
#
# Eliminate columns 1 and 3. Remaining strategy for Player 2 is:
#
#
#    2
# c (4, 4)
#
#
# The strictly dominant strategy for Player 1 is c, and for Player 2 is 2.
#
#
# The Nash Equilibrium for the given game is (c, 2).

# %% [markdown]
# **question2**
#
#
# To find the mixed-strategy Nash Equilibrium, we need to calculate the expected payoffs for each firm and set them equal for both strategies to find the probabilities
#
# p and q.
#
# Let's calculate Firm A's expected payoff for each of its strategies:
#
#
# **Firm A's expected payoff for Strategy I:**
#
# E
# A
# ​
#  (I)=−5q+5(1−q)
#
#  E
# A
# ​
#  (I)=−5q+5−5q
#
#  E
# A
# ​
#  (I)=5−10q
#
#
# **Firm A's expected payoff for Strategy II:**
#
# E
# A
# ​
#  (II)=5q+(−5)(1−q)
#
#  E
# A
# ​
#  (II)=5q−5+5q
#
#  E
# A
# ​
#  (II)=10q−5
#
#  For Firm A to be indifferent between Strategy I and Strategy II, their expected payoffs must be equal:
#
#  5−10q=10q−5
#
#  5+5=10q+10q
#
#  10=20q
#
#  q= 1/2
#
#
#
#  Firm B's Expected Payoff
#
# Similarly, **let's calculate Firm B's expected payoff for each of its strategies:**
#
# **Firm B's expected payoff for Strategy I:**
#
# E
# B
# ​
#  (I)=3p+(−2)(1−p)
#
#  E
# B
# ​
#  (I)=3p−2+2p
#
#  E
# B
# ​
#  (I)=5p−2
#
#  **Firm B's expected payoff for Strategy II:**
#
#
#  E
# B
# ​
#  (II)=−2p+3(1−p)
#
#  E
# B
# ​
#  (II)=−2p+3−3p
#
#  E
# B
# ​
#  (II)=3−5p
#
#  For Firm B to be indifferent between Strategy I and Strategy II, their expected payoffs must be equal:
#
#  5p−2=3−5p
#
#  5p+5p=3+2
#
#  10p=5
#
#
# p=1/2
#
#
#
# **Assumptions:**
#
# Both firms are risk-neutral and aim to maximize their expected payoffs.
#
#
# The payoffs represent the profit/loss outcomes based on the chosen strategies.
#
#
# Both firms have the same set of strategies available and adopt mixed strategies.
#
#
# Each firm knows the payoff matrix and the mixed strategy of the other firm.
#
# **Approach:**
#
# Calculate the expected payoffs for each firm's strategies.
#
#
# Set the expected payoffs equal to find the probabilities that make the firms indifferent between their strategies.
#
#
# Solve for the probabilities
#
# p and
#
# q.
#
#  the mixed-strategy Nash Equilibrium for both firms is to adopt Strategy I with a probability of 1/2 and Strategy II with a probability of 1/2.
#
# ​

# %% [markdown]
# **question3**
